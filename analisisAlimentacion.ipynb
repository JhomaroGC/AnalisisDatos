# %%
pip install bar_chart_race
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import csv
import pandas as pd
import numpy as np
from datetime import datetime
import bar_chart_race as bcr

# %%
df = pd.read_csv('content/007.tablaConsumoBeneficioParques.csv')
df['Fecha'] = df['Created'].str.split(' ', expand=True)[0]
df['Fecha'] = pd.to_datetime(df['Fecha'], format='%d/%m/%Y')
df['Fecha'] = df['Fecha'].dt.strftime('%Y-%m-%d')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                30000 non-null  int64
#  1   Title             29999 non-null  object
#  2   opcion            30000 non-null  object
#  3   tipoAlimentacion  30000 non-null  object
#  4   nombre            30000 non-null  object
#  5   ceco              30000 non-null  int64
#  6   Fecha             30000 non-null  object
#  7   Modified          30000 non-null  object
#  8   Modified By       30000 non-null  object
#  9   Created           30000 non-null  object
#  10  Created By        30000 non-null  object
#  11  Title.1           29999 non-null  object
#  12  rol               29946 non-null  object
#  13  sedeColaborador   28449 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 3.2+ MB

# %%
df['Tienda'] = df['opcion'].str.split(':', expand=True)[0].str.title()
df['Sede']  = df['Title']
df['Tipologia'] = df['tipoAlimentacion']
df_refinado = df[['Fecha','Sede', 'Tienda', 'Tipologia','nombre']]
df_refinado.head()
# Out:
#         Fecha Sede                 Tienda           Tipologia  \
# 0  2025-12-19  Arv  Tienda Yurley Zapata            LiquidoPm
# 1  2025-12-19  Zun                Newrest           LiquidoPm
# 2  2025-12-19  Zun                Newrest  LiquidoComplemento
# 3  2025-12-19  Zun                Newrest              Minuta
# 4  2025-12-19  Est   La Estrella Doña Ana  LiquidoComplemento
#
#                        nombre
# 0  Juliana Monsalve Benavides
# 1   Luis Alfredo Garcia Reyes
# 2   Luis Alfredo Garcia Reyes
# 3   Luis Alfredo Garcia Reyes
# 4     Luz Adriana Gomez Serna
